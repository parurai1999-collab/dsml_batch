# %% [markdown]
# **DICTIONARY**
#
# **Mapping Type is Dictionary**

# %%
data = {
    "id" : "101",
    "name" : "Jane",
    "is_active" : True,
    "roles" : ["Admin", "Editor"]

}

# %% [markdown]
# **Checking data type**

# %%
print(type(data))

# %% [markdown]
# **Creating a dictionary**

# %%
dict({"name" :"paru", "roll_no" : 12})
# Out:
# {'name': 'paru', 'roll_no': 12}

# %%
students = dict({"student1": dict({"name": "paru", "age": 30}),
'student2' : dict({"name":"Ram", "age": 32})})
students
# Out:
# {'student1': {'name': 'paru', 'age': 30},
#  'student2': {'name': 'Ram', 'age': 32}}

# %% [markdown]
# **Create Dictionary from sequence having each item as pair**

# %%
person = dict([("name", "rita"), ("country","nepal"),("telephone", 980000000)])
print(person)
# Out:
# {'name': 'rita', 'country': 'nepal', 'telephone': 980000000}

# %%
data_new ={
    "name": "adf",
    "age": 34
}

# %%
data_new["name"]
# Out:
# 'adf'

# %%
data_new.get("name")
# Out:
# 'adf'

# %%
data_new["name"] = "Ram"
data_new
# Out:
# {'name': 'Ram', 'age': 34}

# %% [markdown]
# **Dictionary Methods**

# %% [markdown]
# **key() method**

# %%
data_new.keys()
# Out:
# dict_keys(['name', 'age'])

# %% [markdown]
# **value() method**

# %%
data_new.values()
# Out:
# dict_values(['Ram', 34])

# %% [markdown]
# **item() method**

# %%
data_new.items()
# Out:
# dict_items([('name', 'Ram'), ('age', 34)])

# %% [markdown]
# **popitem() method**

# %%
data_new.popitem()
# Out:
# ('age', 34)

# %% [markdown]
# **del method**

# %%
data2 = {
    "name" : "eff"
}
data2
# Out:
# {'name': 'eff'}

# %%
del data2

# %%
data2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_9831/2440524255.py in <cell line: 0>()
# ----> 1 data2
#
# NameError: name 'data2' is not defined

# %% [markdown]
# **pop() method**

# %%
data3 = {
    "name" : "gef",
    "age": 34
}
data3

# %%
data3.pop()

# %% [markdown]
# **Join Dictionary (update)**

# %%
dict1 = {
    "Name": "egef",
}
dict2 = {
         "Roll_no": 23}
dict.update(dict2)
dict1
# Out:
# {'Name': 'egef'}

# %% [markdown]
# **Join** **Dictionary** (**Kargs**(**)) **bold text**

# %%
d1 = {"name": "wfef"}
d2 = {"roll_no": 34}
d3 = {"age": 23}
d4 = {**d1, **d2, **d3}
d4
# Out:
# {'name': 'wfef', 'roll_no': 34, 'age': 23}

# %% [markdown]
# **Merge Dictionary**

# %% [markdown]
# **Union**

# %%
d1|d2
# Out:
# {'name': 'wfef', 'roll_no': 34}

# %% [markdown]
# **sorted() method in Dictionary**

# %%
student = {"b": 2, "a": 1, "c": 3}
result = sorted(student)
print(result)
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# **Class Task**

# %% [markdown]
# Create a dictionary to store student name, age, and faculty.
# **bold text**Add a new key called phone to an existing dictionary. **bold text**

# %%
student1 ={
    "name": "Paru",
    "age": 23,
    "faculty": "science",
}
student1["phone"] = 980000000
student1
# Out:
# {'name': 'Paru', 'age': 23, 'faculty': 'science', 'phone': 980000000}

# %% [markdown]
# Update the value of age in a dictionary.
# **bold text**

# %%
student2 = {
    "age" : 34
}
student1.update(student2)
student1
# Out:
# {'name': 'Paru', 'age': 34, 'faculty': 'science'}

# %% [markdown]
# Remove a key named city from a dictionary using del.
# **bold text**

# %%
student1["city"] = "kathmandu"

del student1["city"]
student1
# Out:
# {'name': 'Paru', 'age': 23, 'faculty': 'science', 'phone': 980000000}

# %% [markdown]
# **Check whether the key email exists in a dictionary.**

# %%
if 'email' in student1:
    print("Email exist")
else:
  print('Email doesnot exist')
# Out:
# Email doesnot exist
