# %% [markdown]
# **Tuple** & **Set**

# %%
data = (1,2,3,5,6)
type(data)
# Out:
# tuple

# %%
data1 = (1,2, "hari", [8,6,9], (5,3,6), 5.6)
tuple(data1)
# Out:
# (1, 2, 'hari', [8, 6, 9], (5, 3, 6), 5.6)

# %%
tuple(((1,2, "hari", [8,6,9], (5,3,6), 5.6)))
# Out:
# (1, 2, 'hari', [8, 6, 9], (5, 3, 6), 5.6)

# %%
data2 = (1,2,3,4,5,6,7)
len(data2)
# Out:
# 7

# %%
max(data2)
# Out:
# 7

# %%
min(data2)
# Out:
# 1

# %%
sum(data2)
# Out:
# 28

# %%
sorted(data2)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %% [markdown]
# **Unpacking**

# %%
data4 = (1,2,4)
a,b,c = data4

# %% [markdown]
# -  -means skip

# %%
data5 = (3,4,5)
l,b,_ = data5
print(l)
print(b)
# Out:
# 3
# 4

# %%
t = (10, 20, 30)
print(t[1])
# Out:
# 20

# %%
t1 = (10, 20, 30, 40)
print(t[1:3])
# Out:
# (20, 30)

# %%
t1 = (1,2)
t2 = (3,4)
print(t1 + t2)
# Out:
# (1, 2, 3, 4)

# %%
t = (1,2)
print(t * 3)
# Out:
# (1, 2, 1, 2, 1, 2)

# %%
t = (10, 20, 30)
print(20 in t)
# Out:
# True

# %%
t1 = (1,2)
t2 = (1,3)
print(t1<t2)
# Out:
# True

# %%
t1 = (1,2)
t2 = (1,3)
print(t1>t2)
# Out:
# False

# %% [markdown]
# Tuple does allow item deletion
#
# But we delete whole tuple

# %%
data6 = (1,2,3,4,5)

# %%
del data6[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_18115/1076783142.py in <cell line: 0>()
# ----> 1 del data6[0]
#
# NameError: name 'data6' is not defined

# %% [markdown]
# **SET**

# %%
d = {1,2,3,4,5,6}
type(d)
# Out:
# set

# %%
sample_set = {"mark",}
print(sample_set)
# Out:
# {'mark'}

# %%
set({"hello", 123})
# Out:
# {123, 'hello'}

# %%
a = {1,2,3,4,5,6}
b = {5,6,7,8,9}
a-b
print("diff:",a-b)
# Out:
# diff: {1, 2, 3, 4}

# %% [markdown]
# SET UNION (|)

# %%
print(a|b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# SET INTERSECTION (&)

# %%
print(a & b)
# Out:
# {5, 6}

# %% [markdown]
# SYMMETRIC DIFFERENCE (^)

# %%
print(a^b)
# Out:
# {1, 2, 3, 4, 7, 8, 9}

# %% [markdown]
# MEMBERSHIP (in) SET

# %%
print(19 in a)
# Out:
# False

# %% [markdown]
# SUBSET (<=)

# %%
print(a<=b)
# Out:
# False
