# %% [markdown]
# **Exploration** (**pandas**)

# %% [markdown]
# Data Exploration in Pandas is the process of examining, understanding,
# and summarizing a dataset before performing analysis or modeling.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/dsml_pandas/titanic (1).csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# **Normalize**

# %%
# value(0-1) range ma rakdinxa

# %%
df.value_counts(["Sex", "Survived"])
# Out:
# Sex     Survived
# male    0           468
# female  1           233
# male    1           109
# female  0            81
# Name: count, dtype: int64

# %%
df.value_counts(["Sex", "Survived"], normalize = True)
# Out:
# Sex     Survived
# male    0           0.525253
# female  1           0.261504
# male    1           0.122334
# female  0           0.090909
# Name: proportion, dtype: float64

# %%
468/891
# Out:
# 0.5252525252525253

# %% [markdown]
# **correlation** **and** **covariance**
#
# 2 ota or more variable ko relation (dependent kati xa herni ho)
#
# study time vs result = high/low/medium
#
# age vs shoes size
#
# To see relationaship between them is called correlation and covariance

# %%
df.value_counts(["Sex", "Survived"], normalize = True, ascending = True)
# Out:
# Sex     Survived
# female  0           0.090909
# male    1           0.122334
# female  1           0.261504
# male    0           0.525253
# Name: proportion, dtype: float64

# %%
survived_female = df[(df['Survived'] == 1) & (df['Sex'] == 'female')]
survived_female
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].nunique()
# Out:
# 3

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Using groupby()
df.groupby(['Embarked', 'Survived']).mean(numeric_only = True)
# Out:
#                    PassengerId    Pclass        Age     SibSp     Parch  \
# Embarked Survived
# C        0          409.853333  2.200000  33.666667  0.253333  0.253333
#          1          473.989247  1.634409  28.973671  0.494624  0.451613
# Q        0          480.404255  2.936170  30.325000  0.510638  0.276596
#          1          319.966667  2.866667  22.500000  0.300000  0.000000
# S        0          449.868852  2.545667  30.203966  0.611241  0.348946
#          1          448.857143  1.967742  28.113184  0.493088  0.539171
#
#                         Fare
# Embarked Survived
# C        0         35.443335
#          1         79.720926
# Q        0         13.335904
#          1         13.182227
# S        0         20.743987
#          1         39.547081

# %% [markdown]
# Difference between Correlation and Covariance

# %%
df[["Age", "Fare"]].cov()
# Out:
#              Age         Fare
# Age   211.019125    73.849030
# Fare   73.849030  2469.436846

# %%
df[["Age", "Fare"]].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.096067
# Fare  0.096067  1.000000

# %% [markdown]
# **Sampling**

# %%
sampled = df.sample(n=100, random_state=42)

# %%
sampled[["Age", "Fare"]].corr()
# Out:
#            Age      Fare
# Age   1.000000  0.148739
# Fare  0.148739  1.000000

# %%
 df[(df['Survived'] == 1) & df["Sex"] ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Build a Survival Profile :
#
# You are hired as a data analyst to identify
# the "most likely survivor.
#
# "
# Task:
#
# Analyze survival by:
#
# Gender
#
# Passenger Class
#
# Age Group
#
# Fare
#
# Based on your findings, describe the
# characteristics of a passenger with the
# highest chance of survival.

# %%
df.groupby("Sex")["Survived"].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
df.groupby("Pclass")["Survived"].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
bins = [0,12,18,35,60,100]
labels = ["child", "Teens", "Young", "Adult", "Old"]
df["Age_Group"] = pd.cut(df["Age"], bins = bins, labels = labels)
df["Age_Group"]
# Out:
# 0      Young
# 1      Adult
# 2      Young
# 3      Young
# 4      Young
#        ...
# 886    Young
# 887    Young
# 888      NaN
# 889    Young
# 890    Young
# Name: Age_Group, Length: 891, dtype: category
# Categories (5, object): ['child' < 'Teens' < 'Young' < 'Adult' < 'Old']

# %% [markdown]
# Embarkation Port Analysis:
#
# The company wants to know which port contributed the most passengers.
#
# Task:
#
# Count passengers from each embarkation port (Embarked).
#
# Calculate the survival rate for each port.
#
# Identify the port with the highest survival rate

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df.groupby("Embarked")["Survived"].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.336957
# Name: Survived, dtype: float64

# %%
summary = df.groupby("Embarked")["Survived"].agg(["count", "mean"])
summary.columns = ["Passenger_Count", "Survival_Rate"]
summary
# Out:
#           Passenger_Count  Survival_Rate
# Embarked
# C                     168       0.553571
# Q                      77       0.389610
# S                     644       0.336957
