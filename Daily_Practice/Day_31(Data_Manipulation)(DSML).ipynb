# %% [markdown]
# **Data** **Manipulation**

# %%
# Data Manipulation
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/dsml_pandas/titanic (1).csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Inserting** **and** **Deleting** **Columns** **&** **Rows**

# %%
df.drop("PassengerId", axis=1, inplace=True)
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 1  female  38.0      1      0          PC 17599  71.2833   C85        C
# 2  female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0      1      0            113803  53.1000  C123        S
# 4    male  35.0      0      0            373450   8.0500   NaN        S

# %%
if "PassengerId" in df.columns:
    df.drop("PassengerId", axis=1, inplace=True)
    df.head()

# %%
df.drop([0,2,5], axis = 0, inplace = False).head()
# Out:
#    Survived  Pclass                                               Name  \
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
# 6         0       1                            McCarthy, Mr. Timothy J
# 7         0       3                     Palsson, Master. Gosta Leonard
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 1  female  38.0      1      0  PC 17599  71.2833   C85        C
# 3  female  35.0      1      0    113803  53.1000  C123        S
# 4    male  35.0      0      0    373450   8.0500   NaN        S
# 6    male  54.0      0      0     17463  51.8625   E46        S
# 7    male   2.0      3      1    349909  21.0750   NaN        S

# %% [markdown]
# **Inserting a Column**

# %%
# Inserting a Column
last_name = [name.split(",")[0] for name in df["Name"]]
df["last_name"] = last_name

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df["Middle_name"] = "ABC"

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %% [markdown]
# **Inserting a Row**

# %%
# Insert into row
df.loc[900,:] = [0,3,"Paru, Rai", "male", 22.0, 1.0, "A5 3456", 7.45, 1, "a", "a",0,"ABC"]
# Out:
# /tmp/ipykernel_6711/1343623501.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'A5 3456' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[900,:] = [0,3,"Paru, Rai", "male", 22.0, 1.0, "A5 3456", 7.45, 1, "a", "a",0,"ABC"]

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                            Braund, Mr. Owen Harris
# 1         1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0     3.0                             Heikkinen, Miss. Laina
# 3         1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0     3.0                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 887       1.0     1.0                       Graham, Miss. Margaret Edith
# 888       0.0     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0     1.0                              Behr, Mr. Karl Howell
# 890       0.0     3.0                                Dooley, Mr. Patrick
# 900       0.0     3.0                                          Paru, Rai
#
#         Sex   Age  SibSp    Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
df.loc[901] = {
    "Survived": 0,
    "Pclass": 3,
    "Name": "Hari, Rai",
    "Sex": "male",
    "Age": 23.0,
    "SibSp": 2.0,
    "Ticket": "A5 4556",
    "Fare": 6.45,
    "Cabin": 2,
    "Embarked": "a",
    "middle_name": "a",
    "SomeColumn": 0,
    "Middle_class": "ABC"
}

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                            Braund, Mr. Owen Harris
# 1         1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0     3.0                             Heikkinen, Miss. Laina
# 3         1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0     3.0                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 888       0.0     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0     1.0                              Behr, Mr. Karl Howell
# 890       0.0     3.0                                Dooley, Mr. Patrick
# 900       0.0     3.0                                          Paru, Rai
# 901       0.0     3.0                                          Hari, Rai
#
#         Sex   Age  SibSp    Parch            Ticket     Fare Cabin Embarked  \
# ...

# %% [markdown]
# **Handling** **of** **NaN** **or** **Null** **Values**

# %%
df.isna() # is null
# Out:
#      Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket   Fare  \
# 0       False   False  False  False  False  False  False   False  False
# 1       False   False  False  False  False  False  False   False  False
# 2       False   False  False  False  False  False  False   False  False
# 3       False   False  False  False  False  False  False   False  False
# 4       False   False  False  False  False  False  False   False  False
# ..        ...     ...    ...    ...    ...    ...    ...     ...    ...
# 888     False   False  False  False   True  False  False   False  False
# 889     False   False  False  False  False  False  False   False  False
# 890     False   False  False  False  False  False  False   False  False
# 900     False   False  False  False  False  False  False   False  False
# 901     False   False  False  False  False  False   True   False  False
#
#      Cabin  Embarked  last_name  Middle_name
# 0     True     False      False        False
# ...

# %%
df.isna().sum()
# Out:
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            1
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# last_name        1
# Middle_name      1
# dtype: int64

# %% [markdown]
# **Handling** **NaN** **or** **Null** **Values**
# 1) **remove** **null** **values**(**x**)
# 2) **imputation** (**Replacing** **Null** **with** **some** **value**)

# %% [markdown]
# **Removing Null Values**

# %%
# Removing null values
df_filter = df.dropna(subset = "Embarked", axis = 0, how = "all", ignore_index = True)

# %%
df_filter.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0     3.0                             Heikkinen, Miss. Laina
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0     3.0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0    1.0   0.0         A/5 21171   7.2500   NaN        S
# 1  female  38.0    1.0   0.0          PC 17599  71.2833   C85        C
# 2  female  26.0    0.0   0.0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0    1.0   0.0            113803  53.1000  C123        S
# 4    male  35.0    0.0   0.0            373450   8.0500   NaN        S
#
#    last_name Middle_name
# 0     Braund         ABC
# 1    Cumings         ABC
# 2  Heikkinen         ABC
# ...

# %%
# df_filter.isna().sum()
# Out:
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            1
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# last_name        1
# Middle_name      1
# dtype: int64

# %%
# df_filter = df.dropna(subset = "Cabin", axis = 0, how = "all", ignore_index = True)

# %%
df_filter.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 1       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 2       0.0     1.0                            McCarthy, Mr. Timothy J
# 3       1.0     3.0                    Sandstrom, Miss. Marguerite Rut
# 4       1.0     1.0                           Bonnell, Miss. Elizabeth
#
#       Sex   Age  SibSp Parch    Ticket     Fare Cabin Embarked  last_name  \
# 0  female  38.0    1.0   0.0  PC 17599  71.2833   C85        C    Cumings
# 1  female  35.0    1.0   0.0    113803  53.1000  C123        S   Futrelle
# 2    male  54.0    0.0   0.0     17463  51.8625   E46        S   McCarthy
# 3  female   4.0    1.0   1.0   PP 9549  16.7000    G6        S  Sandstrom
# 4  female  58.0    0.0   0.0    113783  26.5500  C103        S    Bonnell
#
#   Middle_name
# 0         ABC
# 1         ABC
# 2         ABC
# 3         ABC
# 4         ABC

# %%
df_filter.isna().sum()
# Out:
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            19
# SibSp           0
# Parch           1
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        2
# last_name       1
# Middle_name     1
# dtype: int64

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0     3.0                             Heikkinen, Miss. Laina
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0     3.0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp Parch            Ticket     Fare Cabin Embarked  \
# 0    male  22.0    1.0   0.0         A/5 21171   7.2500   NaN        S
# 1  female  38.0    1.0   0.0          PC 17599  71.2833   C85        C
# 2  female  26.0    0.0   0.0  STON/O2. 3101282   7.9250   NaN        S
# 3  female  35.0    1.0   0.0            113803  53.1000  C123        S
# 4    male  35.0    0.0   0.0            373450   8.0500   NaN        S
#
#    last_name Middle_name
# 0     Braund         ABC
# 1    Cumings         ABC
# 2  Heikkinen         ABC
# ...

# %%
df.isna().sum()
# Out:
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            1
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# last_name        1
# Middle_name      1
# dtype: int64

# %%
print(df.Age.mean())
# Out:
# 29.679008379888266

# %%
df.Age.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
mean_age = df.Age.mean()

# %%
df.isna().sum()
# Out:
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            1
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# last_name        1
# Middle_name      1
# dtype: int64

# %% [markdown]
# Jun bela value tite derai farak pardai na tete bela mean use garnu parxa

# %%
df["Age"].fillna(mean_age, axis = 0, inplace = True)

# %%
df.isna().sum()
# Out:
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            1
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# last_name        1
# Middle_name      1
# dtype: int64

# %%
df.Age.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
#  **Imputation Of Age Column w.r.t gender provided**

# %%
df_2 = pd.read_csv("/content/drive/MyDrive/dsml_pandas/titanic (1).csv")

# %%
df_2.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
mean_ages = df_2.groupby("Sex")["Age"].transform("mean")

# %%
df_2["Age"].fillna(mean_ages, inplace = True)
# Out:
# /tmp/ipykernel_6711/438204326.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_2["Age"].fillna(mean_ages, inplace = True)

# %%
df_2.Age.plot.hist(bins = 20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Feature From Null Values
df.Cabin
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 888     NaN
# 889    C148
# 890     NaN
# 900       a
# 901       2
# Name: Cabin, Length: 893, dtype: object

# %%
df.Cabin = df.Cabin.notna().astype(int)

# %%
df.isna().sum()
# Out:
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          1
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# last_name      1
# Middle_name    1
# dtype: int64

# %%
df.Age.plot.box()
# Out:
# <Axes: >

# %%
df.Cabin.plot.box()
# Out:
# <Axes: >

# %% [markdown]
#  Handling Null Value for Age, using initials(Mr., Miss or Master) groups

# %%
titles = df["Name"].str.split(",")
df["Title"] = titles.str[1].str.strip().str.split(" ").str[0]
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0     3.0                             Heikkinen, Miss. Laina
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0     3.0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.0    1.0   0.0         A/5 21171   7.2500      0        S
# 1  female  38.0    1.0   0.0          PC 17599  71.2833      1        C
# 2  female  26.0    0.0   0.0  STON/O2. 3101282   7.9250      0        S
# 3  female  35.0    1.0   0.0            113803  53.1000      1        S
# 4    male  35.0    0.0   0.0            373450   8.0500      0        S
#
#    last_name Middle_name  Title
# 0     Braund         ABC    Mr.
# 1    Cumings         ABC   Mrs.
# ...

# %% [markdown]
# **Cleaning** **Duplicates**

# %%
# Cleaning Duplicates
df[df.duplicated(subset = "Sex")]
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 2         1.0     3.0                        Heikkinen, Miss. Laina  female
# 3         1.0     1.0  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4         0.0     3.0                      Allen, Mr. William Henry    male
# 5         0.0     3.0                              Moran, Mr. James    male
# 6         0.0     1.0                       McCarthy, Mr. Timothy J    male
# ..        ...     ...                                           ...     ...
# 888       0.0     3.0      Johnston, Miss. Catherine Helen "Carrie"  female
# 889       1.0     1.0                         Behr, Mr. Karl Howell    male
# 890       0.0     3.0                           Dooley, Mr. Patrick    male
# 900       0.0     3.0                                     Paru, Rai    male
# 901       0.0     3.0                                     Hari, Rai    male
#
# ...

# %%
df.drop_duplicates().head()
# Out:
#    Survived  Pclass                                               Name  \
# 0       0.0     3.0                            Braund, Mr. Owen Harris
# 1       1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2       1.0     3.0                             Heikkinen, Miss. Laina
# 3       1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4       0.0     3.0                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp Parch            Ticket     Fare  Cabin Embarked  \
# 0    male  22.0    1.0   0.0         A/5 21171   7.2500      0        S
# 1  female  38.0    1.0   0.0          PC 17599  71.2833      1        C
# 2  female  26.0    0.0   0.0  STON/O2. 3101282   7.9250      0        S
# 3  female  35.0    1.0   0.0            113803  53.1000      1        S
# 4    male  35.0    0.0   0.0            373450   8.0500      0        S
#
#    last_name Middle_name  Title
# 0     Braund         ABC    Mr.
# 1    Cumings         ABC   Mrs.
# ...

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0         0.0     3.0                            Braund, Mr. Owen Harris
# 1         1.0     1.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1.0     3.0                             Heikkinen, Miss. Laina
# 3         1.0     1.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0.0     3.0                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 888       0.0     3.0           Johnston, Miss. Catherine Helen "Carrie"
# 889       1.0     1.0                              Behr, Mr. Karl Howell
# 890       0.0     3.0                                Dooley, Mr. Patrick
# 900       0.0     3.0                                          Paru, Rai
# 901       0.0     3.0                                          Hari, Rai
#
#         Sex        Age  SibSp    Parch            Ticket     Fare  Cabin  \
# ...
