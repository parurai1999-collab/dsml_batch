# %% [markdown]
# **Python Function**

# %%
Syntax
def function_name(parameter):
  //code....
  return value

# %%
function(argument or value)

# %%
def sum(a,b):
  sumd = a+b
  return sumd
  print(sumd(2,4))

# %% [markdown]
# **No Parameters, No return**

# %%
def greet():
  print("Hello! World to Python.")
  print("Have a great day!")
  return greet()

# %% [markdown]
# **Has Parameter, No return**

# %%
def greet(name):
  print("Hello", {name})
  return greet("Ram")

# %% [markdown]
# **Has parameter, has return**

# %%
def ab(a,b):
  print(a+b)
  return sum
  print(sum(2,4))

# %%
user = input("Your name:")
def name(user):
  print("Good morning", user)
name(user)
# Out:
# Your name:paru
# Good morning paru

# %% [markdown]
# Write a Python program using User Defined Function
# (UDF) that:
# Takes two numbers from the user
# Takes an operator sign (+, -,*, /)
# Performs the selected operation
# Displays the result.

# %%
a = float(input("Enter the first number:"))
b = float(input("Enter the second number:"))
c = input("Enter the operator:(+, -, *, /)")

def cal(a, b, c):
    if c == "+":
        print(a+b)
    elif c == "-":
        print(a-b)
    elif c == "*":
        print(a*b)
    elif c == "/":
        print(a/b)


cal(a, b, c)
# Out:
# Enter the first number:2
# Enter the second number:3
# Enter the operator:(+, -, *, /)+
# 5.0

# %% [markdown]
# Write a function area(length, breadth) that returns the
# area of rectangle.

# %%
def area(l, b):
    return l*b


l = float(input("Enter the first number:"))
b = float(input("Enter the second number:"))


print("Area of rectangle:", area(l, b))
# Out:
# Enter the first number:6
# Enter the second number:76
# Area of rectangle: 456.0

# %% [markdown]
# Write a user-defined function that takes 5 user inputs.
# If the user enters an integer, add it to a list
# If the user enters a float number, remove the last element

# %%
lst = []


def num():
    for i in range(5):
        user = input("Enter the number: ")

        if "." in user:
            if lst:
                lst.pop()
                print(lst)
            else:
                print(lst)

        else:
            value = int(user)
            lst.append(value)
            print(lst)


num()
# Out:
# Enter the number: 1
# [1]
# Enter the number: 2
# [1, 2]
# Enter the number: 3.4
# [1]
# Enter the number: 9
# [1, 9]
# Enter the number: 4
# [1, 9, 4]

# %% [markdown]
# **Two** **error**
#
# **syntax** **error**
#
# **logical** **error**
