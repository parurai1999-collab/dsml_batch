# %% [markdown]
# # Welcome to Colab!

# %%
import math
print(math.floor(44.9))
print(round(44.5))
# Out:
# 44
# 44

# %%
text1 = "Its a sunny day"
text2 = 'He said "Hello"'
print(text1)
print(text2)
print(text1.strip())
# Out:
# Its a sunny day
# He said "Hello"

# %% [markdown]
# **Sequence** **of** **character** **is** **String**.

# %%
text1 = 'a'
text2 = 'b'
sum_text = text1 + text2
print(sum_text)
print(text1 + " " + text2)
print(text1 * 3)
print(text1[0])
# Out:
# ab
# a b
# aaa
# a

# %%
# data[start:end:step]
data = 'python'
print(data[1:4])
print(data[:-1])
print(data[1:4:2])
text = "Hello Python"
print(text[1:11])
print(len(data))
print(len(text))
# Out:
# yth
# pytho
# yh
# ello Pytho
# 6
# 12

# %% [markdown]
# **Concatation**
# **Slicing**

# %%
data = "Python"
print(data.upper())
print(data.lower())
print(data.title())
print(data.split())
print(data.replace('P','R'))
print(data.strip()) # Removes the space of starting and ending
# Out:
# PYTHON
# python
# Python
# ['Python']
# Rython
# Python

# %% [markdown]
# **String** **Operations**
# upper(), lower(), title(), strip(), split(), replace()

# %%
data5 = "image.png"
data5.endswith('png')
# Out:
# True

# %%
number = 122
print(type(number))
# Out:
# <class 'int'>

# %% [markdown]
# **Data** **Type**-> **Numbers**, **Float**, **Complex**
#
# **type() -> Know the type of data**

# %%
num = 3.4
print(type(num))
# Out:
# <class 'float'>

# %%
com = 3 + 3j
type(com)
# Out:
# complex

# %%
a = 3
b =4
add = a+b
sub = a-b
mul = a*b
div = a/b
mod = a%b
expo = a**b
floor = a//b
print(floor)
print(expo)
print(mod)
print(add)
print(sub)
print(mul)
print(div)
# Out:
# 0
# 81
# 3
# 7
# -1
# 12
# 0.75

# %%
a = 4
b = 5
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# **Comparison** **Operators**

# %%
num = 4.5
print(int(num))
# Out:
# 4
